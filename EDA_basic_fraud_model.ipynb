# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('C:/Users/Acer/Desktop/fraud_model/card_data.csv') 
print(data.columns)
data.head()
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# ...

# %%
print(data.shape)
print(data.describe())
# Out:
# (284807, 31)
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
import seaborn as sns
amount = [data['Amount'].values]
sns.distplot(amount) #plotting distribution

# %%
time = data['Time'].values #no. of seconds elapsed from the first transaction and this transaction in DB
sns.distplot(time) #plotting distribution

# %%
from matplotlib import gridspec
# distribution of anomalous features
features = data.iloc[:,0:28].columns

plt.figure(figsize=(12,28*4))
gs = gridspec.GridSpec(28, 1)
for i, c in enumerate(data[features]): #loop through all features
    ax = plt.subplot(gs[i])
    sns.distplot(data[c][data.Class == 1], bins=30) #label = fraud
    sns.distplot(data[c][data.Class == 0], bins=30) #label = non-fraud
    ax.set_xlabel('')
    ax.set_title('histogram of feature: ' + str(c))
plt.show()

# %%
# Plot histograms of each parameter 
data.hist(figsize = (20, 20))
import matplotlib.pyplot as plt
plt.show()

# %%
# Segregate fraud & non-fraud cases in dataset

fraud = data[data['Class'] == 1]
valid = data[data['Class'] == 0]
#print(fraud)
#print(valid)


print('Fraud Cases:', len(data[data['Class'] == 1]))
print('Valid Transactions:', len(data[data['Class'] == 0]))

fraud_fraction = len(fraud)/float(len(valid))
print('Fraction of Fraud Cases:', fraud_fraction)
# Out:
# Fraud Cases: 492
# Valid Transactions: 284315
# Fraction of Fraud Cases: 0.0017304750013189597

# %%
print("Details of Amt. of fradulent transacation")
fraud.Amount.describe()
# Out:
# Details of Amt. of fradulent transacation
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
print("Details of Amt. of valid transaction")
valid.Amount.describe()
# Out:
# Details of Amt. of valid transaction
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# Correlation matrix
corrmat = data.corr()
fig = plt.figure(figsize = (12, 9))

sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()
